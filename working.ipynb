# %%
import xml.etree.ElementTree as ET  
tree = ET.parse('books_xml/21.xml')  
root = tree.getroot()

# one specific item attribute
'''print('Item #2 attribute:')  
print(root[0][1].attrib)

# all item attributes
print('\nAll attributes:')  
#for elem in root:  
 #   for subelem in elem:
  #      print(subelem.attrib)

# one specific item's data
print('\nItem #2 data:')  
print(root[0][1].text)
'''
# all items data
#print('\nAll item data:')
for elem in root:  
    for subelem in elem:
        print(subelem.text)
# Out:
# true
# all_men_must_serve
# book_show
# 21
# A Short History of Nearly Everything
# 076790818X
# 9780767908184
# None
# B0035OC7VI
# A1F83G8C2ARO7P
# GB
# https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png
# https://s.gr-assets.com/assets/nophoto/book/50x75-a91bf249278a81aabab721ef782c4a74.png
# None
# None
# None
# None
# en-US
# false
# ...

# %%
arr=os.listdir('books_xml')
count=0
n=0
for val in arr:
    tree = ET.parse('books_xml/'+val)  
    root = tree.getroot()
    isbn_val=0
    desc_text=" "
    id=0
    title=" "
    isbn=0
    isbn13=0
    country_code=" "
    publication_year=" "
    language_code=" "
    description=" "
    average_rating=0
    num_pages=0
    ratings_count=0
    authors=" "
    features = ["id","title","isbn","isbn13","country_code","publication_year","language_code","description","average_rating","num_pages","ratings_count","authors"]
    for elem in root:
        for sublem in elem:
            if(sublem.tag=='publication_year'):
                if(sublem.text!=None):
                    count+=1
                else:
                    print(val)
print(count)
print(n)
# Out:
# 379316.xml
# 13168.xml
# 9654.xml
# 17660462.xml
# 38030.xml
# 72855.xml
# 22321.xml
# 32254.xml
# 9791.xml
# 278102.xml
# 34897.xml
# 68520.xml
# 207802.xml
# 33288638.xml
# 12542.xml
# 207687.xml
# 69242.xml
# 243601.xml
# 91476.xml
# 6871646.xml
# 5152561.xml
# 25176.xml
# 4701.xml
# 29639736.xml
# 47520.xml
# 8765461.xml
# 18906484.xml
# 5182.xml
# 22027459.xml
# 42900.xml
# 556511.xml
# 5957702.xml
# 2983489.xml
# 597.xml
# 8459594.xml
# 1062516.xml
# 2761626.xml
# 40440.xml
# 79790.xml
# 2227371.xml
# 42697.xml
# 14069.xml
# 334643.xml
# 765148.xml
# 8702806.xml
# 12609.xml
# 34262.xml
# 409918.xml
# 2285777.xml
# 2318271.xml
# 6589074.xml
# 68210.xml
# 47944.xml
# 250.xml
# 93793.xml
# 29405093.xml
# 97860.xml
# 520738.xml
# 23675858.xml
# 6324903.xml
# 54120.xml
# 291354.xml
# 24807.xml
# 281350.xml
# 13134.xml
# 289695.xml
# 372385.xml
# 92303.xml
# 31106.xml
# 400924.xml
# 3121162.xml
# 10566.xml
# 820956.xml
# 6977769.xml
# 15171.xml
# 21726.xml
# 29397.xml
# 27810589.xml
# ...

# %%
d={"id":np.nan,"title":np.nan,"isbn":np.nan,"isbn13":np.nan,"country_code":np.nan,"publication_year":np.nan,"language_code":np.nan,"description":np.nan,"average_rating":np.nan,"num_pages":np.nan,"ratings_count":np.nan,"authors":np.nan}
df=pd.DataFrame([d])
arr=os.listdir('books_xml')
for val in arr:
    tree = ET.parse('books_xml/'+val)  
    root = tree.getroot()
    id_=0
    title=" "
    isbn=0
    isbn13=0
    country_code=" "
    publication_year=" "
    language_code=" "
    description=" "
    average_rating=0
    num_pages=0
    ratings_count=0
    authors=" "
    features = ["id","title","isbn","isbn13","country_code","publication_year","language_code","description","average_rating","num_pages","ratings_count","authors"]
    for elem in root:
        for sublem in elem:
            if(sublem.tag=='id'):
                if(sublem.text!=None):
                    id_=sublem.text
                else:
                    id_=np.nan
            elif(sublem.tag=='title'):
                if(sublem.text!=None):
                    title=sublem.text
                else:
                    title=np.nan
            elif(sublem.tag=='isbn'):
                if(sublem.text!=None):
                    isbn=sublem.text
                else:
                    isbn=np.nan
            elif(sublem.tag=='isbn13'):
                if(sublem.text!=None):
                    isbn13=sublem.text
                else:
                    isbn13=np.nan
            elif(sublem.tag=='country_code'):
                if(sublem.text!=None):
                    country_code=sublem.text
                else:
                    country_code=np.nan
            elif(sublem.tag=='publication_year'):
                if(sublem.text!=None):
                    publication_year=sublem.text
                else:
                    publication_year=np.nan
            elif(sublem.tag=='language_code'):
                if(sublem.text!=None):
                    language_code=sublem.text
                else:
                    language_code=np.nan
            elif(sublem.tag=='description'):
                if(sublem.text!=None):
                    description=sublem.text
                else:
                    description=np.nan
            elif(sublem.tag=='average_rating'):
                if(sublem.text!=None):
                    average_rating=sublem.text
                else:
                    average_rating=np.nan
            elif(sublem.tag=='num_pages'):
                if(sublem.text!=None):
                    num_pages=sublem.text
                else:
                    num_pages=np.nan
            elif(sublem.tag=='ratings_count'):
                if(sublem.text!=None):
                    ratings_count=sublem.text
                else:
                    ratings_count=np.nan
            elif(sublem.tag=='authors'):
                if(sublem.text!=None):
                    authors=sublem.text
                else:
                    authors=np.nan
    df=df.append([{"id":id_,"title":title,"isbn":isbn,"isbn13":isbn13,"country_code":country_code,"publication_year":publication_year,"language_code":language_code,"description":description,"average_rating":average_rating,"num_pages":num_pages,"ratings_count":ratings_count,"authors":authors}])

# %%
p={'hi':['1','5'],'hello':['e','h']}
p['hi']=[p['hi'],'3']
p['hi']=[p['hi'],'3']

# %%
our_data=df
our_data.to_csv('book_temp_data.csv',index=False)

# %%
dff=pd.read_csv('books.csv')

# %%
dff.loc[(dff.book_id==9654),'original_publication_year']
# Out:
# 9653    1998.0
# Name: original_publication_year, dtype: float64

# %%
df.rename({"id":"book_id"}, axis="columns", inplace=True)

# %%
def chng(x):
    x['book_id']=float(x['book_id'])
    return x

# %%
our_data=our_data.apply(chng,axis=1)

# %%
hello=our_data

# %%
our_data.columns
# Out:
# Index(['authors', 'average_rating', 'country_code', 'description', 'book_id',
#        'isbn', 'isbn13', 'language_code', 'num_pages', 'publication_year',
#        'ratings_count', 'title'],
#       dtype='object')

# %%
dataframe=our_data.drop(['authors', 'average_rating', 'country_code','language_code', 'num_pages', 'publication_year',
       'ratings_count'],axis=1)

# %%
dataframe=dataframe.reset_index()

# %%
dataframe=dataframe.drop('index',axis=1)

# %%
dataframe.head()
# Out:
#                                          description     book_id        isbn  \
# 0                                                NaN         NaN         NaN
# 1  When NYPD Red arrives at a crime scene, everyo...  18170134.0  0316211265
# 2  "Yer eyes'll shine when ye see the rivers runn...     66692.0  088038672X
# 3  <i>Mistborn: Secret History</i> is a companion...  28698036.0         NaN
# 4                                                NaN    379316.0  0553804820
#
#           isbn13                                              title
# 0            NaN                                                NaN
# 1  9780316211260                          NYPD Red 2 (NYPD Red, #2)
# 2  9780880386722  Streams of Silver (Forgotten Realms: Icewind D...
# 3            NaN                    Secret History (Mistborn, #3.5)
# 4  9780553804829                    The Darkest Evening of the Year

# %%
dff.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780061e+12                   Harper Lee                     1960.0
# 4  9.780743e+12          F. Scott Fitzgerald                     1925.0
#
#                              original_title  ... ratings_count  \
# ...

# %%
mine=pd.read_csv('book_temp_data.csv')

# %%
mine.columns
# Out:
# Index(['authors', 'average_rating', 'country_code', 'description', 'id',
#        'isbn', 'isbn13', 'language_code', 'num_pages', 'publication_year',
#        'ratings_count', 'title'],
#       dtype='object')

# %%
dff.sort_values(by='isbn')
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 488       489               2547          2547   2938937          721
# 9427     9428             313998        313998    304846           18
# 2668     2669              45100         45100   1476156           56
# 6501     6502             316845        316845   2457438           70
# 6188     6189             244572        244572   6594671           70
# 6683     6684              16326         16326    820002          179
# 1979     1980              24830         24830   1065861          123
# 346       347             121749        121749   3348636          348
# 5432     5433            6489529       6489529   6680918           55
# 3210     3211            2410506       2410506   2417683           87
# 9130     9131           18161265      18161265  25521824           48
# 8777     8778           10868182      10868182   1600165           86
# ...

# %%
mine.sort_values(by='isbn')
# Out:
#      authors  average_rating country_code  \
# 1307      \n            4.22           GB
# 9016      \n            4.16           GB
# 2901      \n            3.75           GB
# 3866      \n            3.70           GB
# 5667      \n            3.88           GB
# 3484      \n            3.91           GB
# 2521      \n            3.95           GB
# 8357      \n            3.82           GB
# 7877      \n            3.73           GB
# 6272      \n            3.65           GB
# 6784      \n            3.91           GB
# 8761      \n            4.28           GB
# 8626      \n            4.14           GB
# 225       \n            4.16           GB
# 725       \n            4.12           GB
# 2296      \n            4.08           GB
# 7302      \n            3.61           GB
# 6623      \n            4.09           GB
# 5248      \n            3.78           GB
# 2071      \n            4.14           GB
# 3783      \n            4.01           GB
# ...

# %%
dff3.head(10)
# Out:
#   authors average_rating country_code  \
# 0      \n           3.44           GB
# 1      \n           4.09           GB
# 2      \n           3.77           GB
# 3      \n           4.05           GB
# 4      \n           3.46           GB
# 5      \n           3.68           GB
# 6      \n           4.28           GB
# 7      \n           3.82           GB
# 8      \n           3.85           GB
# 9      \n           3.57           GB
#
#                                          description  book_id        isbn  \
# 0  <b>Bored with her marriage, a psychoanalyst’s ...   9654.0  0451209435
# 1  Charles Carter—a.k.a. Carter the Great—is a yo...   4599.0  0786886323
# 2  The ground shifts repeatedly beneath the reade...   9864.0  0312254997
# 3  Subtitle: Rediscovering America on the Appalac...   9791.0  0307279464
# 4  George Hall is an unobtrusive man. A little di...   4701.0  0385520514
# 5  <i>Songs in Ordinary Time</i> is set in the su...   5182.0  0140244824
# ...

# %%
dff3['original_publication_year'].head()
# Out:
# 0    1998.0
# 1    2012.0
# 2    2001.0
# 3    2015.0
# 4    1975.0
# Name: original_publication_year, dtype: float64

# %%
dff3=our_data.merge(dff2,on='book_id')

# %%
dff2=dff.drop(['goodreads_book_id', 'best_book_id', 'work_id',
       'books_count', 'isbn', 'isbn13', 'authors','original_title', 'title', 'language_code', 'average_rating','ratings_count', 'work_ratings_count', 'work_text_reviews_count','ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5','image_url', 'small_image_url'],axis=1)

# %%
dff2.columns
# Out:
# Index(['book_id', 'original_publication_year'], dtype='object')

# %%
dff2.isnull().sum()
# Out:
# book_id                       0
# original_publication_year    21
# dtype: int64

# %%
df.isnull().sum()
# Out:
# authors                1
# average_rating         1
# country_code           1
# description          316
# id                     1
# isbn                 701
# isbn13               586
# language_code       1084
# num_pages            900
# publication_year    2236
# ratings_count          1
# title                  1
# dtype: int64

# %%
df1.loc[(df1.original_publication_year<1000),'isbn']
# Out:
# 78       143039954
# 340      140275363
# 402     1590302257
# 530      393320979
# 771      140449140
# 823     1580495931
# 1098     679776192
# 1119     192840509
# 1279     679729526
# 1520    1580493882
# 1909     812972147
# 1966     140449337
# 2051    015602764X
# 2075     141026286
# 2081           NaN
# 2141     147712556
# 2335     140449183
# 2365    014044789X
# 2762     486275485
# 3255     192833723
# 3403     140449086
# 3867     140449272
# 3929     140449493
# 3948     486414248
# 4148     140443339
# 4329     872205541
# 4331     140440399
# 4536     872206033
# 4879     865163480
# 5636     938077872
# 6165    069109750X
# 6895     872206335
# 7777     140443487
# 8471    1888009039
# 8632     140449213
# 9280     521010756
# 9303     140446362
# 9678     140441638
# Name: isbn, dtype: object

# %%
id
title
isbn
isbn13
country_code
publication_yer
language_code
escription
average_rating
num_pages
ratings_count
authors
popular_shelves

# %%
import pandas as pd

# %%
d={'isbn13':0,'description':"hi"}
df=pd.DataFrame([d])

# %%
import os

# %%
import numpy as np

# %%
arr=os.listdir('books_xml')
for val in arr:
    tree = ET.parse('books_xml/'+val)  
    root = tree.getroot()
    isbn_val=0
    desc_text=" "
    for elem in root:
        for sublem in elem:
            if(sublem.tag=='isbn13'):
                if(sublem.text!=None):
                    isbn_val=sublem.text
                else:
                    isbn_val=np.nan
            if(sublem.tag=='description'):
                if(sublem.text!=None):
                    desc_text=sublem.text
                else:
                    desc_text=np.nan
    df=df.append([{'isbn13':isbn_val,'description':desc_text}])

# %%
#id
#title
#isbn
#isbn13
#country_code
#publication_yer
#language_code
#description
#average_rating
#num_pages
#ratings_count
#authors
#popular_shelves

# %%
df.shape
# Out:
# (0, 2)

# %%
df=df.drop(0)

# %%
df=df.reset_index()
df=df.drop('index',axis=1)

# %%
def remove_tags(x):
    b=''
    c=1
    print(type(x))
    for a in x:
        if(a=='<'):
            c=0
        if(c==1):
            b+=a
        if(a=='>'):
            c=1
    return b

# %%
df['description'].apply(remove_tags)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'NoneType'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-deec0f983326> in <module>
# ----> 1 df['description'].apply(remove_tags)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
#    3590                 values = self.astype(object).values
# -> 3591                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3592
#    3593         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-84-68439875fce6> in remove_tags(x)
#       3     c=1
#       4     print(type(x))
# ----> 5     for a in x:
#       6         if(a=='<'):
#       7             c=0
#
# TypeError: 'NoneType' object is not iterable

# %%
(df.head(5))
# Out:
# Empty DataFrame
# Columns: [description, isbn13]
# Index: []

# %%
genres=["Art", "Biography", "Business", "Chick Lit", "Children's", "Christian", "Classics", "Comics", "Contemporary", "Cookbooks", "Crime", "Ebooks", "Fantasy", "Fiction", "Gay and Lesbian", "Graphic Novels", "Historical Fiction", "History", "Horror", "Humor and Comedy", "Manga", "Memoir", "Music", "Mystery", "Nonfiction", "Paranormal", "Philosophy", "Poetry", "Psychology", "Religion", "Romance", "Science", "Science Fiction", "Self Help", "Suspense", "Spirituality", "Sports", "Thriller", "Travel", "Young Adult"]

# %%
genres[0]
# Out:
# 'Art'

# %%
df.isna().sum()
# Out:
# description     630
# isbn           1400
# dtype: int64

# %%
df.head()
# Out:
#                                          description         isbn13
# 0                                                 hi              0
# 0  When NYPD Red arrives at a crime scene, everyo...  9780316211260
# 0  "Yer eyes'll shine when ye see the rivers runn...  9780880386722
# 0  <i>Mistborn: Secret History</i> is a companion...            NaN
# 0                                                NaN  9780553804829

# %%
df.isna().sum()
# Out:
# description    315
# isbn13         585
# dtype: int64

# %%
df=df.reset_index()

# %%
df=df.drop('index',axis=1)

# %%
df=df.drop(0)

# %%
df.head()
# Out:
#                                          description         isbn13
# 0  When NYPD Red arrives at a crime scene, everyo...  9780316211260
# 1  "Yer eyes'll shine when ye see the rivers runn...  9780880386722
# 2  <i>Mistborn: Secret History</i> is a companion...            NaN
# 3                                                NaN  9780553804829
# 4  Banksy, Britain's now-legendary "guerilla" str...  9781844137879

# %%
df.to_csv('desc.csv')

# %%
df=pd.read_csv('desc.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0                                        description        isbn13
# 0           0  When NYPD Red arrives at a crime scene, everyo...  9.780316e+12
# 1           1  "Yer eyes'll shine when ye see the rivers runn...  9.780880e+12
# 2           2  <i>Mistborn: Secret History</i> is a companion...           NaN
# 3           3                                                NaN  9.780554e+12
# 4           4  Banksy, Britain's now-legendary "guerilla" str...  9.781844e+12

# %%
df.shape
# Out:
# (10000, 3)

# %%
df=df.drop('a',axis=1)

# %%
df.rename({"Unnamed: 0":"a"}, axis="columns", inplace=True)

# %%
df.isna().sum()
# Out:
# description    315
# isbn13         585
# dtype: int64

# %%
import numpy as np

# %%
df=df.dropna()

# %%
df.isna().sum()
# Out:
# description    0
# isbn13         0
# dtype: int64

# %%
df1=pd.read_csv('books.csv')

# %%
df1['isbn13'].unique()
# Out:
# array([9.78043902e+12, 9.78043955e+12, 9.78031602e+12, ...,
#        9.78039331e+12, 9.78006171e+12, 9.78037570e+12])

# %%
df['check']=0

# %%
df.head()
# Out:
#                                          description        isbn13  check
# 0  When NYPD Red arrives at a crime scene, everyo...  9.780316e+12      0
# 1  "Yer eyes'll shine when ye see the rivers runn...  9.780880e+12      0
# 4  Banksy, Britain's now-legendary "guerilla" str...  9.781844e+12      0
# 5  <i>The Artist’s Way</i> is the seminal book on...  9.781585e+12      0
# 6  Marianne Daventry will do anything to escape t...  9.781609e+12      0

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-104-12f8cec3479c> in <module>
# ----> 1 df['check'] = (df['isbn13'] == df1['isbn13']).all(axis=1).astype(int)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1674
#    1675         elif isinstance(other, ABCSeries) and not self._indexed_same(other):
# -> 1676             raise ValueError("Can only compare identically-labeled "
#    1677                              "Series objects")
#    1678
#
# ValueError: Can only compare identically-labeled Series objects

# %%
df.columns
# Out:
# Index(['description', 'isbn13', 'check'], dtype='object')

# %%
df1.columns
# Out:
# Index(['book_id', 'goodreads_book_id', 'best_book_id', 'work_id',
#        'books_count', 'isbn', 'isbn13', 'authors', 'original_publication_year',
#        'original_title', 'title', 'language_code', 'average_rating',
#        'ratings_count', 'work_ratings_count', 'work_text_reviews_count',
#        'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5',
#        'image_url', 'small_image_url'],
#       dtype='object')

# %%
df1=df1.merge(df,on='isbn13')

# %%
df1.isnull().sum()
# Out:
# book_id                        0
# goodreads_book_id              0
# best_book_id                   0
# work_id                        0
# books_count                    0
# isbn                          14
# isbn13                         0
# authors                        0
# original_publication_year      2
# original_title                45
# title                          0
# language_code                104
# average_rating                 0
# ratings_count                  0
# work_ratings_count             0
# work_text_reviews_count        0
# ratings_1                      0
# ratings_2                      0
# ratings_3                      0
# ratings_4                      0
# ratings_5                      0
# image_url                      0
# small_image_url                0
# description                    0
# dtype: int64

# %%
df1.shape
# Out:
# (926, 24)

# %%
df1['original_publication_year'].unique().shape
# Out:
# (294,)

# %%
df1.loc[(df1.original_publication_year<1000),'original_publication_year']=np.nan

# %%
df1 = df1.dropna()

# %%
df1.shape
# Out:
# (7827, 23)

# %%
df1=df1.drop(['goodreads_book_id','best_book_id','work_id','books_count','work_ratings_count','work_text_reviews_count','ratings_1','ratings_2','ratings_3','ratings_4','ratings_5','image_url','small_image_url'],axis=1)

# %%
df1.head()
# Out:
#    book_id       isbn        isbn13                      authors  \
# 0        1  439023483  9.780439e+12              Suzanne Collins
# 1        2  439554934  9.780440e+12  J.K. Rowling, Mary GrandPré
# 2        3  316015849  9.780316e+12              Stephenie Meyer
# 3        4   61120081  9.780061e+12                   Harper Lee
# 4        5  743273567  9.780743e+12          F. Scott Fitzgerald
#
#    original_publication_year                            original_title  \
# 0                     2008.0                          The Hunger Games
# 1                     1997.0  Harry Potter and the Philosopher's Stone
# 2                     2005.0                                  Twilight
# 3                     1960.0                     To Kill a Mockingbird
# 4                     1925.0                          The Great Gatsby
#
#                                                title language_code  \
# 0            The Hunger Games (The Hunger Games, #1)           eng
# ...

# %%
df1.to_csv('book_data.csv',index=False)

# %%
df2=pd.read_csv('book_data.csv')

# %%
df2.head()
# Out:
#    book_id       isbn        isbn13                      authors  \
# 0        1  439023483  9.780439e+12              Suzanne Collins
# 1        2  439554934  9.780440e+12  J.K. Rowling, Mary GrandPré
# 2        3  316015849  9.780316e+12              Stephenie Meyer
# 3        4   61120081  9.780061e+12                   Harper Lee
# 4        5  743273567  9.780743e+12          F. Scott Fitzgerald
#
#    original_publication_year                            original_title  \
# 0                     2008.0                          The Hunger Games
# 1                     1997.0  Harry Potter and the Philosopher's Stone
# 2                     2005.0                                  Twilight
# 3                     1960.0                     To Kill a Mockingbird
# 4                     1925.0                          The Great Gatsby
#
#                                                title language_code  \
# 0            The Hunger Games (The Hunger Games, #1)           eng
# ...

# %%
df2.isnull().sum()
# Out:
# book_id                      0
# isbn                         0
# isbn13                       0
# authors                      0
# original_publication_year    0
# original_title               0
# title                        0
# language_code                0
# average_rating               0
# ratings_count                0
# dtype: int64
